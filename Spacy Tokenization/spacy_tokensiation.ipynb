# %%
import spacy

# %%
nlp = spacy.blank('en')

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai as it costs only 2$ per plate.")
for token in doc:
    print(token)
# Out:
# Dr.
# Strange
# loves
# pav
# bhaji
# of
# mumbai
# as
# it
# costs
# only
# 2
# $
# per
# plate
# .

# %%
type(nlp)
# Out:
# spacy.lang.en.English

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
type(token)
# Out:
# spacy.tokens.token.Token

# %%
doc_1 = doc[1:5]
type(doc_1)
# Out:
# spacy.tokens.span.Span

# %%
doc = nlp("Tony gave two $ to Peter.")

# %%
token0 = doc[0]
token0
# Out:
# Tony

# %%
dir(token0)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
#  'is_punct',
#  'is_quote',
#  'is_right_punct',
#  'is_sent_end',
#  'is_sent_start',
#  'is_space',
#  'is_stop',
#  'is_title',
#  'is_upper',
#  'lang',
#  'lang_',
#  'left_edge',
#  'lefts',
#  'lemma',
#  'lemma_',
#  'lex',
#  'lex_id',
#  'like_email',
#  'like_num',
#  'like_url',
#  'lower',
#  'lower_',
#  'morph',
#  'n_lefts',
#  'n_rights',
#  'nbor',
#  'norm',
#  'norm_',
#  'orth',
#  'orth_',
#  'pos',
#  'pos_',
#  'prefix',
#  'prefix_',
#  'prob',
#  'rank',
#  'remove_extension',
#  'right_edge',
#  'rights',
#  'sent',
#  'sent_start',
#  'sentiment',
#  'set_extension',
#  'set_morph',
#  'shape',
#  'shape_',
#  'similarity',
#  'subtree',
#  'suffix',
#  'suffix_',
#  'tag',
#  'tag_',
#  'tensor',
#  'text',
#  'text_with_ws',
#  'vector',
#  'vector_norm',
#  'vocab',
#  'whitespace_']

# %%
token0.is_alpha
# Out:
# True

# %%
token0.like_num
# Out:
# False

# %%
token2 = doc[2]
token2
# Out:
# two

# %%
token2.like_num
# Out:
# True

# %%
for token in doc:
    print(token, "==>", "index", token.i, 
          "is_alpha", token.is_alpha,
          "like_num", token.like_num,
          "is_punct", token.is_punct,
          "is_currency", token.is_currency)
# Out:
# Tony ==> index 0 is_alpha True like_num False is_punct False is_currency False
# gave ==> index 1 is_alpha True like_num False is_punct False is_currency False
# two ==> index 2 is_alpha True like_num True is_punct False is_currency False
# $ ==> index 3 is_alpha False like_num False is_punct False is_currency True
# to ==> index 4 is_alpha True like_num False is_punct False is_currency False
# Peter ==> index 5 is_alpha True like_num False is_punct False is_currency False
# . ==> index 6 is_alpha False like_num False is_punct True is_currency False

# %% [markdown]
# Collecting email ids of students from students information sheet

# %%
with open ('students (1).txt') as f:
    text = f.readlines()
text
# Out:
# ['Dayton high school, 8th grade students information\n',
#  '==================================================\n',
#  '\n',
#  'Name\tbirth day   \temail\n',
#  '-----\t------------\t------\n',
#  'Virat   5 June, 1882    virat@kohli.com\n',
#  'Maria\t12 April, 2001  maria@sharapova.com\n',
#  'Serena  24 June, 1998   serena@williams.com \n',
#  'Joe      1 May, 1997    joe@root.com\n',
#  '\n',
#  '\n',
#  '\n']

# %%
text = ''.join(text)
text
# Out:
# 'Dayton high school, 8th grade students information\n==================================================\n\nName\tbirth day   \temail\n-----\t------------\t------\nVirat   5 June, 1882    virat@kohli.com\nMaria\t12 April, 2001  maria@sharapova.com\nSerena  24 June, 1998   serena@williams.com \nJoe      1 May, 1997    joe@root.com\n\n\n\n'

# %%
doc = nlp(text)
email=[]
for token in doc:
    if token.like_email:
        email.append(token)

email
# Out:
# [virat@kohli.com, maria@sharapova.com, serena@williams.com, joe@root.com]

# %% [markdown]
# other languages

# %%
nlp = spacy.blank("hi")
doc = nlp("भैया जी! 5000 ₹ उधार थे वो वापस देदो")
for token in doc:
    print(token, token.is_currency)
# Out:
# भैया False
# जी False
# ! False
# 5000 False
# ₹ True
# उधार False
# थे False
# वो False
# वापस False
# देदो False

# %% [markdown]
# Customizing Spacy tokenizer

# %%
doc = nlp("gimme double cheese extra large healthy pizza")
tokens = [token.text for token in doc]
tokens
# Out:
# ['gimme', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %%
from spacy.symbols import ORTH
nlp.tokenizer.add_special_case('gimme',[
    {ORTH:'give'},
    {ORTH:'me'}
])

doc = nlp("gimme double cheese extra large healthy pizza")
tokens = [token.text for token in doc]
tokens
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 from spacy.symbols import ORTH
# ----> 2 nlp.tokenizer.add_special_case('gimme',[
#       3     {ORTH:'give'},
#       4     {ORTH:'me'}
#       5 ])
#       7 doc = nlp("gimme double cheese extra large healthy pizza")
#       8 tokens = [token.text for token in doc]
#
# File D:\kk\conda\conda_installation\Lib\site-packages\spacy\tokenizer.pyx:610, in spacy.tokenizer.Tokenizer.add_special_case()
#
# File D:\kk\conda\conda_installation\Lib\site-packages\spacy\tokenizer.pyx:594, in spacy.tokenizer.Tokenizer._validate_special_case()
#
# ValueError: [E997] Tokenizer special cases are not allowed to modify the text. This would map 'gimme' to 'giveme' given token attributes '[{65: 'give'}, {65: 'me'}]'.

# %%
from spacy.symbols import ORTH
nlp.tokenizer.add_special_case('gimme',[
    {ORTH:'gim'},
    {ORTH:'me'}
])

doc = nlp("gimme double cheese extra large healthy pizza")
tokens = [token.text for token in doc]
tokens
# Out:
# ['gim', 'me', 'double', 'cheese', 'extra', 'large', 'healthy', 'pizza']

# %% [markdown]
# Sentence Tokenization or Segmentation

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
for sentence in doc.sents:
    print(sentence)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
# ----> 2 for sentence in doc.sents:
#       3     print(sentence)
#
# File D:\kk\conda\conda_installation\Lib\site-packages\spacy\tokens\doc.pyx:926, in sents()
#
# ValueError: [E030] Sentence boundaries unset. You can add the 'sentencizer' component to the pipeline with: `nlp.add_pipe('sentencizer')`. Alternatively, add the dependency parser or sentence recognizer, or set sentence boundaries by setting `doc[i].is_sent_start`.

# %%
nlp.pipeline
# Out:
# []

# %%
nlp.pipe_names
# Out:
# []

# %% [markdown]
# because we imported blank spacy en only

# %%
nlp.add_pipe('sentencizer')

# %%
nlp.pipe_names
# Out:
# ['sentencizer']

# %%
nlp.pipeline
# Out:
# [('sentencizer', <spacy.pipeline.sentencizer.Sentencizer at 0x13c272ae610>)]

# %%
doc = nlp("Dr. Strange loves pav bhaji of mumbai. Hulk loves chat of delhi")
for sentence in doc.sents:
    print(sentence)
# Out:
# Dr.
# Strange loves pav bhaji of mumbai.
# Hulk loves chat of delhi
